# %% [markdown]
# <a href="https://colab.research.google.com/github/AlbertoMartinezS/idal_ia3/blob/main/dnn_mnist.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Entrenamiento de un Perceptrón Multi-Capa con datos de dígitos (MNIST)

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.layers import Dense, BatchNormalization, Dropout
import matplotlib.pyplot as plt
tf.random.set_seed(42)

# %% [markdown]
# ## Carga de los datos
# #### Tamaño del conjunto de entrenamiento y de test

# %%
(X_train, y_train), (X_test, y_test) = tf.keras.datasets.mnist.load_data()

print(' -Entradas Entrenamiento:', X_train.shape)
print(' -Salidas Entrenamiento:', y_train.shape)
print(' -Entradas Test:', X_test.shape)
print(' -Salidas Test:', y_test.shape)
# Out:
#  -Entradas Entrenamiento: (60000, 28, 28)
#  -Salidas Entrenamiento: (60000,)
#  -Entradas Test: (10000, 28, 28)
#  -Salidas Test: (10000,)

# %% [markdown]
# #### Visualización de las entradas

# %%
n_img_show = 3

# Plot images
plt.figure(figsize=(16,10))
for i in range(n_img_show):
    plt.subplot(1, n_img_show, i+1)
    plt.imshow(X_train[i], cmap='gray')
    plt.colorbar(fraction=0.046)
    plt.axis('off');

print(f'Valores de salida correspondientes a las imágenes de entrada {y_train[0:n_img_show]}')
# Out:
# Valores de salida correspondientes a las imágenes de entrada [5 0 4]

# %% [markdown]
# ## Preparación de los datos
# #### Normalización

# %%
# Normalizamos a valores entre 0 y 1
X_train = X_train.astype('float32')/255
X_test = X_test.astype('float32')/255

plt.figure(figsize=(16,10))
for i in range(n_img_show):
    plt.subplot(1, n_img_show, i+1)
    plt.imshow(X_train[i], cmap='gray')
    plt.colorbar(fraction=0.046)
    plt.axis('off');

# %% [markdown]
# #### Reajuste del tamaño de la entrada y la salida

# %%
x_shape = X_train.shape
X_train = X_train.reshape(x_shape[0], x_shape[1]*x_shape[2])
X_test = X_test.reshape(len(X_test), x_shape[1]*x_shape[2])
y_train = y_train[:, None]
y_test = y_test[:, None]

# Dibujar la nueva entrada
plt.figure(figsize=(20, 70))
plt.imshow(X_train[0:100], cmap='gray')
plt.xlabel('# Pixeles')
plt.ylabel('# Imágenes')
plt.colorbar(fraction=0.006);

# %% [markdown]
# ## Definición del modelo
# Crea un modelo con las siguientes capas:
# 1. Capa de entrada con tantas entradas como número de píxeles (784)
# 2. Capa oculta con 256 neuronas
# 3. Capa oculta con 128 neuronas
# 4. Capa oculta con 64 neuronas
# 5. Capa oculta con 32 neuronas
# 6. Capa de salidad con tantas neuronas como salidas (10)
#
# Todas las capas usan función de activación relu (menos la de salida). ¿Qué función de activación hay que poner a la salida?

# %%
# Algunos hiper-parámetros
lr = .001
batch_size = 512
n_epochs = 35
optimizer = tf.keras.optimizers.Adam(learning_rate=lr)

# Crear modelo
#    
#    
#    

model= tf.keras.models.Sequential()
#model.add(tf.keras.layers.Flatten(input_shape= [28,28])) #(X_train.shape[1])
model.add(Dense(units= 256, activation= 'relu', input_shape= (X_train.shape[1],)))
model.add(Dense(128, activation= 'relu'))
model.add(Dense(64, activation= 'relu'))
model.add(Dense(32, activation= 'relu'))
model.add(Dense(10, activation= 'softmax'))
# Visualizar arquitectura y dimensiones
model.summary()

# Compilamos el modelo: ¿Qué función de coste hay que utilizar?
model.compile(loss='sparse_categorical_crossentropy',
              optimizer=optimizer,
              metrics=['accuracy'])
# Out:
# Model: "sequential_14"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_49 (Dense)            (None, 256)               200960
#
#  dense_50 (Dense)            (None, 128)               32896
#
#  dense_51 (Dense)            (None, 64)                8256
#
#  dense_52 (Dense)            (None, 32)                2080
#
#  dense_53 (Dense)            (None, 10)                330
#
# =================================================================
# Total params: 244,522
# Trainable params: 244,522
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Entrenamiento del modelo

# %%
hist = model.fit(X_train, 
                 y_train, 
                 batch_size=batch_size, 
                 epochs=n_epochs, 
                 verbose=1, 
                 shuffle=True,
                 validation_data=(X_test, y_test))
# Out:
# Epoch 1/35
# 118/118 [==============================] - 3s 17ms/step - loss: 0.5074 - accuracy: 0.8424 - val_loss: 0.2119 - val_accuracy: 0.9364
# Epoch 2/35
# 118/118 [==============================] - 2s 15ms/step - loss: 0.1563 - accuracy: 0.9545 - val_loss: 0.1400 - val_accuracy: 0.9593
# Epoch 3/35
# 118/118 [==============================] - 2s 15ms/step - loss: 0.1090 - accuracy: 0.9676 - val_loss: 0.1010 - val_accuracy: 0.9694
# Epoch 4/35
# 118/118 [==============================] - 2s 15ms/step - loss: 0.0806 - accuracy: 0.9756 - val_loss: 0.1021 - val_accuracy: 0.9679
# Epoch 5/35
# 118/118 [==============================] - 2s 15ms/step - loss: 0.0642 - accuracy: 0.9807 - val_loss: 0.0873 - val_accuracy: 0.9734
# Epoch 6/35
# 118/118 [==============================] - 2s 15ms/step - loss: 0.0507 - accuracy: 0.9846 - val_loss: 0.0789 - val_accuracy: 0.9762
# Epoch 7/35
# 118/118 [==============================] - 2s 15ms/step - loss: 0.0395 - accuracy: 0.9878 - val_loss: 0.0786 - val_accuracy: 0.9771
# Epoch 8/35
# 118/118 [==============================] - 2s 15ms/step - loss: 0.0324 - accuracy: 0.9903 - val_loss: 0.0760 - val_accuracy: 0.9759
# Epoch 9/35
# 118/118 [==============================] - 2s 15ms/step - loss: 0.0265 - accuracy: 0.9923 - val_loss: 0.0738 - val_accuracy: 0.9790
# Epoch 10/35
# 118/118 [==============================] - 2s 15ms/step - loss: 0.0224 - accuracy: 0.9931 - val_loss: 0.0730 - val_accuracy: 0.9796
# Epoch 11/35
# 118/118 [==============================] - 2s 15ms/step - loss: 0.0198 - accuracy: 0.9936 - val_loss: 0.0751 - val_accuracy: 0.9805
# Epoch 12/35
# 118/118 [==============================] - 2s 15ms/step - loss: 0.0151 - accuracy: 0.9954 - val_loss: 0.0744 - val_accuracy: 0.9799
# Epoch 13/35
# 118/118 [==============================] - 2s 15ms/step - loss: 0.0138 - accuracy: 0.9961 - val_loss: 0.0770 - val_accuracy: 0.9795
# Epoch 14/35
# 118/118 [==============================] - 2s 16ms/step - loss: 0.0083 - accuracy: 0.9980 - val_loss: 0.0805 - val_accuracy: 0.9804
# Epoch 15/35
# 118/118 [==============================] - 2s 15ms/step - loss: 0.0152 - accuracy: 0.9951 - val_loss: 0.0934 - val_accuracy: 0.9752
# Epoch 16/35
# 118/118 [==============================] - 2s 16ms/step - loss: 0.0080 - accuracy: 0.9976 - val_loss: 0.0873 - val_accuracy: 0.9792
# Epoch 17/35
# 118/118 [==============================] - 2s 15ms/step - loss: 0.0072 - accuracy: 0.9981 - val_loss: 0.0815 - val_accuracy: 0.9804
# Epoch 18/35
# 118/118 [==============================] - 2s 15ms/step - loss: 0.0029 - accuracy: 0.9995 - val_loss: 0.0814 - val_accuracy: 0.9812
# Epoch 19/35
# 118/118 [==============================] - 2s 16ms/step - loss: 0.0032 - accuracy: 0.9993 - val_loss: 0.0869 - val_accuracy: 0.9804
# Epoch 20/35
# 118/118 [==============================] - 2s 15ms/step - loss: 0.0024 - accuracy: 0.9995 - val_loss: 0.0869 - val_accuracy: 0.9811
# Epoch 21/35
# 118/118 [==============================] - 2s 16ms/step - loss: 0.0014 - accuracy: 0.9998 - val_loss: 0.0842 - val_accuracy: 0.9812
# Epoch 22/35
# 118/118 [==============================] - 2s 16ms/step - loss: 6.9629e-04 - accuracy: 0.9999 - val_loss: 0.0834 - val_accuracy: 0.9825
# Epoch 23/35
# 118/118 [==============================] - 2s 15ms/step - loss: 3.2691e-04 - accuracy: 1.0000 - val_loss: 0.0848 - val_accuracy: 0.9828
# Epoch 24/35
# 118/118 [==============================] - 2s 16ms/step - loss: 2.6120e-04 - accuracy: 1.0000 - val_loss: 0.0869 - val_accuracy: 0.9828
# Epoch 25/35
# 118/118 [==============================] - 2s 16ms/step - loss: 2.0367e-04 - accuracy: 1.0000 - val_loss: 0.0866 - val_accuracy: 0.9831
# Epoch 26/35
# 118/118 [==============================] - 2s 15ms/step - loss: 1.7484e-04 - accuracy: 1.0000 - val_loss: 0.0882 - val_accuracy: 0.9829
# Epoch 27/35
# 118/118 [==============================] - 2s 16ms/step - loss: 1.5550e-04 - accuracy: 1.0000 - val_loss: 0.0888 - val_accuracy: 0.9826
# Epoch 28/35
# 118/118 [==============================] - 2s 15ms/step - loss: 1.3764e-04 - accuracy: 1.0000 - val_loss: 0.0899 - val_accuracy: 0.9830
# Epoch 29/35
# 118/118 [==============================] - 2s 15ms/step - loss: 1.2494e-04 - accuracy: 1.0000 - val_loss: 0.0908 - val_accuracy: 0.9829
# Epoch 30/35
# 118/118 [==============================] - 2s 15ms/step - loss: 1.1523e-04 - accuracy: 1.0000 - val_loss: 0.0913 - val_accuracy: 0.9830
# Epoch 31/35
# 118/118 [==============================] - 2s 15ms/step - loss: 1.0615e-04 - accuracy: 1.0000 - val_loss: 0.0925 - val_accuracy: 0.9829
# Epoch 32/35
# 118/118 [==============================] - 2s 15ms/step - loss: 9.5606e-05 - accuracy: 1.0000 - val_loss: 0.0929 - val_accuracy: 0.9827
# Epoch 33/35
# 118/118 [==============================] - 2s 15ms/step - loss: 8.7659e-05 - accuracy: 1.0000 - val_loss: 0.0935 - val_accuracy: 0.9826
# Epoch 34/35
# 118/118 [==============================] - 2s 15ms/step - loss: 8.1066e-05 - accuracy: 1.0000 - val_loss: 0.0945 - val_accuracy: 0.9827
# Epoch 35/35
# 118/118 [==============================] - 2s 16ms/step - loss: 7.3839e-05 - accuracy: 1.0000 - val_loss: 0.0949 - val_accuracy: 0.9825

# %% [markdown]
# ### Dibujar las curvas de entrenamiento/validación

# %%
def plot_curves(history):
  plt.figure()
  plt.xlabel('Épocas')
  plt.ylabel('Error')
  plt.plot(history['loss'])
  plt.plot(history['val_loss'])
  plt.legend(['Entrenamiento', 'Validación'])

  plt.figure()
  plt.xlabel('Épocas')
  plt.ylabel('Accuracy')
  plt.plot(history['accuracy'])
  plt.plot(history['val_accuracy'])
  plt.legend(['Entrenamiento', 'Validación'], loc='lower right');

plot_curves(hist.history)

# %% [markdown]
# ### Visualización de los pesos

# %%
def plot_weights(model):
  layers = [l for l in model.layers if l.name.startswith('dense')]
  n_img_show = len(layers)
  plt.figure(figsize=(30, 11))
  cnt = 1
  for layer in layers:
      plt.subplot(1, n_img_show, cnt)
      plt.imshow(layer.get_weights()[0])
      plt.title(f'Pesos capa {cnt}')
      plt.colorbar(fraction=0.07)
      cnt += 1

def plot_weights_hist(model):
  layers = [l for l in model.layers if l.name.startswith('dense')]
  n_img_show = len(layers)
  plt.figure(figsize=(30, 5))
  cnt = 1
  for layer in layers:
    if layer.name.startswith('dense'):
      plt.subplot(1, n_img_show, cnt)
      plt.hist(layer.get_weights()[0].flatten(), bins=30)
      plt.title(f'Pesos capa {cnt}')
      mean = np.mean(layer.get_weights()[0])
      std = np.std(layer.get_weights()[0])
      plt.xlabel(f'Valores de los pesos. Media: {mean:.3f} +- {std:.3f}')
      plt.ylabel('cuenta')
      cnt +=1

plot_weights(model)
plot_weights_hist(model)

# %% [markdown]
# ## Regularización del modelo con L2
# Crea un modelo nuevo exactamente igual que el anterior y añade regularización L2 en todas las capas (menos en la de salida, como es obvio). Prueba distintos valores (0.1, 0.01 y 0.001) y observa cual es el comportamiento.

# %%
tf.keras.backend.clear_session()
n_epochs = 50

# Crear modelo
#    .
#    .
#    .
model_with_l2 = tf.keras.models.Sequential()
#model.add(tf.keras.layers.Flatten(input_shape= [28,28])) #(X_train.shape[1])
model_with_l2.add(Dense(units= 256, activation= 'relu', input_shape= (X_train.shape[1],), kernel_regularizer =tf.keras.regularizers.l2(0.0001)))
model_with_l2.add(Dense(128, activation= 'relu', kernel_regularizer =tf.keras.regularizers.l2(0.0001)))
model_with_l2.add(Dense(64, activation= 'relu', kernel_regularizer =tf.keras.regularizers.l2(0.0001)))
model_with_l2.add(Dense(32, activation= 'relu', kernel_regularizer =tf.keras.regularizers.l2(0.0001)))
model_with_l2.add(Dense(10, activation= 'softmax'))


# Compilamos el modelo
model_with_l2.compile(loss='sparse_categorical_crossentropy',
              optimizer=optimizer,
              metrics=['accuracy'])

# Entrenamos
hist = model_with_l2.fit(X_train, 
                         y_train, 
                         batch_size=batch_size, 
                         epochs=n_epochs,
                         verbose=1,
                         shuffle=True, 
                         validation_data=(X_test, y_test))
# Out:
# Epoch 1/50
# 118/118 [==============================] - 3s 17ms/step - loss: 0.4006 - accuracy: 0.8978 - val_loss: 0.2057 - val_accuracy: 0.9548
# Epoch 2/50
# 118/118 [==============================] - 2s 16ms/step - loss: 0.1634 - accuracy: 0.9690 - val_loss: 0.1573 - val_accuracy: 0.9700
# Epoch 3/50
# 118/118 [==============================] - 2s 16ms/step - loss: 0.1294 - accuracy: 0.9785 - val_loss: 0.1423 - val_accuracy: 0.9721
# Epoch 4/50
# 118/118 [==============================] - 2s 16ms/step - loss: 0.1091 - accuracy: 0.9833 - val_loss: 0.1318 - val_accuracy: 0.9769
# Epoch 5/50
# 118/118 [==============================] - 2s 16ms/step - loss: 0.0940 - accuracy: 0.9876 - val_loss: 0.1272 - val_accuracy: 0.9761
# Epoch 6/50
# 118/118 [==============================] - 2s 16ms/step - loss: 0.0854 - accuracy: 0.9902 - val_loss: 0.1242 - val_accuracy: 0.9772
# Epoch 7/50
# 118/118 [==============================] - 2s 16ms/step - loss: 0.0773 - accuracy: 0.9922 - val_loss: 0.1202 - val_accuracy: 0.9782
# Epoch 8/50
# 118/118 [==============================] - 2s 16ms/step - loss: 0.0728 - accuracy: 0.9936 - val_loss: 0.1197 - val_accuracy: 0.9779
# Epoch 9/50
# 118/118 [==============================] - 2s 16ms/step - loss: 0.0678 - accuracy: 0.9942 - val_loss: 0.1175 - val_accuracy: 0.9809
# Epoch 10/50
# 118/118 [==============================] - 2s 16ms/step - loss: 0.0628 - accuracy: 0.9959 - val_loss: 0.1152 - val_accuracy: 0.9793
# Epoch 11/50
# 118/118 [==============================] - 2s 16ms/step - loss: 0.0588 - accuracy: 0.9969 - val_loss: 0.1133 - val_accuracy: 0.9798
# Epoch 12/50
# 118/118 [==============================] - 2s 16ms/step - loss: 0.0593 - accuracy: 0.9958 - val_loss: 0.1223 - val_accuracy: 0.9794
# Epoch 13/50
# 118/118 [==============================] - 2s 16ms/step - loss: 0.0628 - accuracy: 0.9942 - val_loss: 0.1157 - val_accuracy: 0.9810
# Epoch 14/50
# 118/118 [==============================] - 2s 16ms/step - loss: 0.0544 - accuracy: 0.9971 - val_loss: 0.1198 - val_accuracy: 0.9800
# Epoch 15/50
# 118/118 [==============================] - 2s 16ms/step - loss: 0.0529 - accuracy: 0.9973 - val_loss: 0.1207 - val_accuracy: 0.9782
# Epoch 16/50
# 118/118 [==============================] - 2s 16ms/step - loss: 0.0523 - accuracy: 0.9973 - val_loss: 0.1161 - val_accuracy: 0.9791
# Epoch 17/50
# 118/118 [==============================] - 2s 16ms/step - loss: 0.0498 - accuracy: 0.9978 - val_loss: 0.1087 - val_accuracy: 0.9812
# Epoch 18/50
# 118/118 [==============================] - 2s 16ms/step - loss: 0.0443 - accuracy: 0.9993 - val_loss: 0.1089 - val_accuracy: 0.9812
# Epoch 19/50
# 118/118 [==============================] - 2s 16ms/step - loss: 0.0438 - accuracy: 0.9990 - val_loss: 0.1129 - val_accuracy: 0.9813
# Epoch 20/50
# 118/118 [==============================] - 2s 16ms/step - loss: 0.0502 - accuracy: 0.9961 - val_loss: 0.1210 - val_accuracy: 0.9775
# Epoch 21/50
# 118/118 [==============================] - 2s 16ms/step - loss: 0.0533 - accuracy: 0.9955 - val_loss: 0.1059 - val_accuracy: 0.9814
# Epoch 22/50
# 118/118 [==============================] - 2s 16ms/step - loss: 0.0489 - accuracy: 0.9968 - val_loss: 0.1089 - val_accuracy: 0.9810
# Epoch 23/50
# 118/118 [==============================] - 2s 16ms/step - loss: 0.0465 - accuracy: 0.9974 - val_loss: 0.1161 - val_accuracy: 0.9784
# Epoch 24/50
# 118/118 [==============================] - 2s 16ms/step - loss: 0.0446 - accuracy: 0.9979 - val_loss: 0.1047 - val_accuracy: 0.9815
# Epoch 25/50
# 118/118 [==============================] - 2s 16ms/step - loss: 0.0416 - accuracy: 0.9987 - val_loss: 0.1006 - val_accuracy: 0.9833
# Epoch 26/50
# 118/118 [==============================] - 2s 16ms/step - loss: 0.0391 - accuracy: 0.9991 - val_loss: 0.1087 - val_accuracy: 0.9805
# Epoch 27/50
# 118/118 [==============================] - 2s 16ms/step - loss: 0.0371 - accuracy: 0.9995 - val_loss: 0.1078 - val_accuracy: 0.9816
# Epoch 28/50
# 118/118 [==============================] - 2s 16ms/step - loss: 0.0374 - accuracy: 0.9990 - val_loss: 0.1079 - val_accuracy: 0.9804
# Epoch 29/50
# 118/118 [==============================] - 2s 16ms/step - loss: 0.0441 - accuracy: 0.9965 - val_loss: 0.1166 - val_accuracy: 0.9771
# Epoch 30/50
# 118/118 [==============================] - 2s 16ms/step - loss: 0.0514 - accuracy: 0.9938 - val_loss: 0.1203 - val_accuracy: 0.9764
# Epoch 31/50
# 118/118 [==============================] - 2s 16ms/step - loss: 0.0456 - accuracy: 0.9964 - val_loss: 0.1062 - val_accuracy: 0.9816
# Epoch 32/50
# 118/118 [==============================] - 2s 16ms/step - loss: 0.0403 - accuracy: 0.9982 - val_loss: 0.1101 - val_accuracy: 0.9806
# Epoch 33/50
# 118/118 [==============================] - 2s 16ms/step - loss: 0.0400 - accuracy: 0.9980 - val_loss: 0.1001 - val_accuracy: 0.9814
# Epoch 34/50
# 118/118 [==============================] - 2s 16ms/step - loss: 0.0376 - accuracy: 0.9988 - val_loss: 0.1163 - val_accuracy: 0.9779
# Epoch 35/50
# 118/118 [==============================] - 2s 16ms/step - loss: 0.0369 - accuracy: 0.9985 - val_loss: 0.1045 - val_accuracy: 0.9803
# Epoch 36/50
# 118/118 [==============================] - 2s 16ms/step - loss: 0.0336 - accuracy: 0.9995 - val_loss: 0.0980 - val_accuracy: 0.9830
# Epoch 37/50
# 118/118 [==============================] - 2s 16ms/step - loss: 0.0329 - accuracy: 0.9994 - val_loss: 0.0990 - val_accuracy: 0.9813
# Epoch 38/50
# 118/118 [==============================] - 2s 16ms/step - loss: 0.0413 - accuracy: 0.9963 - val_loss: 0.1093 - val_accuracy: 0.9784
# Epoch 39/50
# 118/118 [==============================] - 2s 16ms/step - loss: 0.0513 - accuracy: 0.9934 - val_loss: 0.1282 - val_accuracy: 0.9742
# Epoch 40/50
# 118/118 [==============================] - 2s 16ms/step - loss: 0.0437 - accuracy: 0.9963 - val_loss: 0.1047 - val_accuracy: 0.9813
# Epoch 41/50
# 118/118 [==============================] - 2s 16ms/step - loss: 0.0358 - accuracy: 0.9990 - val_loss: 0.1002 - val_accuracy: 0.9816
# Epoch 42/50
# 118/118 [==============================] - 2s 16ms/step - loss: 0.0353 - accuracy: 0.9986 - val_loss: 0.1023 - val_accuracy: 0.9806
# Epoch 43/50
# 118/118 [==============================] - 2s 16ms/step - loss: 0.0357 - accuracy: 0.9985 - val_loss: 0.0973 - val_accuracy: 0.9822
# Epoch 44/50
# 118/118 [==============================] - 2s 16ms/step - loss: 0.0329 - accuracy: 0.9992 - val_loss: 0.0972 - val_accuracy: 0.9829
# Epoch 45/50
# 118/118 [==============================] - 2s 16ms/step - loss: 0.0296 - accuracy: 0.9999 - val_loss: 0.0927 - val_accuracy: 0.9829
# Epoch 46/50
# 118/118 [==============================] - 2s 16ms/step - loss: 0.0296 - accuracy: 0.9995 - val_loss: 0.0978 - val_accuracy: 0.9824
# Epoch 47/50
# 118/118 [==============================] - 2s 16ms/step - loss: 0.0297 - accuracy: 0.9993 - val_loss: 0.0909 - val_accuracy: 0.9825
# Epoch 48/50
# 118/118 [==============================] - 2s 16ms/step - loss: 0.0322 - accuracy: 0.9983 - val_loss: 0.1087 - val_accuracy: 0.9780
# Epoch 49/50
# 118/118 [==============================] - 2s 16ms/step - loss: 0.0455 - accuracy: 0.9939 - val_loss: 0.1048 - val_accuracy: 0.9799
# Epoch 50/50
# 118/118 [==============================] - 2s 16ms/step - loss: 0.0489 - accuracy: 0.9936 - val_loss: 0.1108 - val_accuracy: 0.9790

# %% [markdown]
# ### Evaluación del modelo con regularización L2

# %%
plot_curves(hist.history)

# %% [markdown]
# ### Visualización de los pesos

# %%
plot_weights(model_with_l2)
plot_weights_hist(model_with_l2)

# %% [markdown]
# ## Regularización del modelo con Dropout
# Ahora crea el mismo modelo pero añade dropout. Prueba distintos valores de dropout.

# %%
tf.keras.backend.clear_session()

# Crear modelo
n_epochs = 25
#    .
#    .
#    .
model_with_dp = tf.keras.models.Sequential()
#model.add(tf.keras.layers.Flatten(input_shape= [28,28])) #(X_train.shape[1])
model_with_dp.add(Dense(units= 256, activation= 'relu', input_shape= (X_train.shape[1],)))
model_with_dp.add(Dropout(0.4))

model_with_dp.add(Dense(128, activation= 'relu'))
model_with_dp.add(Dropout(0.4))

model_with_dp.add(Dense(64, activation= 'relu'))
model_with_dp.add(Dropout(0.4))

model_with_dp.add(Dense(32, activation= 'relu'))
model_with_dp.add(Dropout(0.4))

model_with_dp.add(Dense(10, activation= 'softmax'))

# Compilamos el modelo
model_with_dp.compile(loss='sparse_categorical_crossentropy',
                      optimizer=optimizer,
                      metrics=['accuracy'])

# Entrenamos
hist = model_with_dp.fit(X_train, 
                         y_train, 
                         batch_size=batch_size, 
                         epochs=n_epochs,
                         verbose=1, 
                         shuffle=True, 
                         validation_data=(X_test, y_test))
# Out:
# Epoch 1/25
# 118/118 [==============================] - 3s 20ms/step - loss: 0.8651 - accuracy: 0.7158 - val_loss: 0.2429 - val_accuracy: 0.9365
# Epoch 2/25
# 118/118 [==============================] - 2s 19ms/step - loss: 0.3884 - accuracy: 0.9019 - val_loss: 0.1902 - val_accuracy: 0.9510
# Epoch 3/25
# 118/118 [==============================] - 2s 19ms/step - loss: 0.3119 - accuracy: 0.9262 - val_loss: 0.1554 - val_accuracy: 0.9616
# Epoch 4/25
# 118/118 [==============================] - 2s 19ms/step - loss: 0.2665 - accuracy: 0.9365 - val_loss: 0.1409 - val_accuracy: 0.9653
# Epoch 5/25
# 118/118 [==============================] - 2s 19ms/step - loss: 0.2386 - accuracy: 0.9440 - val_loss: 0.1378 - val_accuracy: 0.9674
# Epoch 6/25
# 118/118 [==============================] - 2s 19ms/step - loss: 0.2202 - accuracy: 0.9467 - val_loss: 0.1252 - val_accuracy: 0.9691
# Epoch 7/25
# 118/118 [==============================] - 2s 19ms/step - loss: 0.1974 - accuracy: 0.9530 - val_loss: 0.1263 - val_accuracy: 0.9704
# Epoch 8/25
# 118/118 [==============================] - 2s 19ms/step - loss: 0.1954 - accuracy: 0.9544 - val_loss: 0.1175 - val_accuracy: 0.9738
# Epoch 9/25
# 118/118 [==============================] - 2s 19ms/step - loss: 0.1821 - accuracy: 0.9570 - val_loss: 0.1172 - val_accuracy: 0.9725
# Epoch 10/25
# 118/118 [==============================] - 2s 19ms/step - loss: 0.1680 - accuracy: 0.9602 - val_loss: 0.1141 - val_accuracy: 0.9741
# Epoch 11/25
# 118/118 [==============================] - 2s 19ms/step - loss: 0.1617 - accuracy: 0.9610 - val_loss: 0.1139 - val_accuracy: 0.9745
# Epoch 12/25
# 118/118 [==============================] - 2s 19ms/step - loss: 0.1585 - accuracy: 0.9631 - val_loss: 0.1162 - val_accuracy: 0.9747
# Epoch 13/25
# 118/118 [==============================] - 2s 19ms/step - loss: 0.1497 - accuracy: 0.9632 - val_loss: 0.1182 - val_accuracy: 0.9746
# Epoch 14/25
# 118/118 [==============================] - 2s 19ms/step - loss: 0.1466 - accuracy: 0.9651 - val_loss: 0.1142 - val_accuracy: 0.9766
# Epoch 15/25
# 118/118 [==============================] - 2s 19ms/step - loss: 0.1402 - accuracy: 0.9660 - val_loss: 0.1181 - val_accuracy: 0.9756
# Epoch 16/25
# 118/118 [==============================] - 2s 19ms/step - loss: 0.1368 - accuracy: 0.9681 - val_loss: 0.1073 - val_accuracy: 0.9781
# Epoch 17/25
# 118/118 [==============================] - 2s 19ms/step - loss: 0.1297 - accuracy: 0.9685 - val_loss: 0.1083 - val_accuracy: 0.9781
# Epoch 18/25
# 118/118 [==============================] - 2s 19ms/step - loss: 0.1279 - accuracy: 0.9700 - val_loss: 0.1107 - val_accuracy: 0.9772
# Epoch 19/25
# 118/118 [==============================] - 2s 19ms/step - loss: 0.1231 - accuracy: 0.9700 - val_loss: 0.1137 - val_accuracy: 0.9778
# Epoch 20/25
# 118/118 [==============================] - 2s 19ms/step - loss: 0.1221 - accuracy: 0.9710 - val_loss: 0.1081 - val_accuracy: 0.9782
# Epoch 21/25
# 118/118 [==============================] - 2s 19ms/step - loss: 0.1195 - accuracy: 0.9707 - val_loss: 0.1125 - val_accuracy: 0.9779
# Epoch 22/25
# 118/118 [==============================] - 2s 19ms/step - loss: 0.1176 - accuracy: 0.9723 - val_loss: 0.1099 - val_accuracy: 0.9764
# Epoch 23/25
# 118/118 [==============================] - 2s 19ms/step - loss: 0.1185 - accuracy: 0.9718 - val_loss: 0.1113 - val_accuracy: 0.9773
# Epoch 24/25
# 118/118 [==============================] - 2s 19ms/step - loss: 0.1098 - accuracy: 0.9739 - val_loss: 0.1056 - val_accuracy: 0.9790
# Epoch 25/25
# 118/118 [==============================] - 2s 19ms/step - loss: 0.1125 - accuracy: 0.9736 - val_loss: 0.1079 - val_accuracy: 0.9778

# %% [markdown]
# ### Evaluación del modelo con Dropout

# %%
# Plots
plot_curves(hist.history)
# plot_weights(model_with_dp)
plot_weights_hist(model_with_dp)
